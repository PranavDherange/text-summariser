# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("D:\\Projects\\text-summariser\\output.csv")
# Out:
# C:\Users\Pranny21\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (10046588, 9)

# %%
df.tail(50)
# Out:
#              tconst  titleType  \
# 10046538  tt9916754      movie
# 10046539  tt9916756      short
# 10046540  tt9916758  tvEpisode
# 10046541  tt9916760  tvEpisode
# 10046542  tt9916762  tvEpisode
# 10046543  tt9916764      short
# 10046544  tt9916766  tvEpisode
# 10046545  tt9916768  tvEpisode
# 10046546  tt9916770  tvEpisode
# 10046547  tt9916774  tvEpisode
# 10046548  tt9916776  tvEpisode
# 10046549  tt9916778  tvEpisode
# 10046550  tt9916780  tvEpisode
# 10046551  tt9916782  tvEpisode
# 10046552  tt9916784  tvEpisode
# 10046553  tt9916786  tvEpisode
# 10046554  tt9916788  tvEpisode
# 10046555  tt9916790  tvEpisode
# 10046556  tt9916792  tvEpisode
# 10046557  tt9916794  tvEpisode
# 10046558  tt9916796  tvEpisode
# 10046559  tt9916798  tvEpisode
# 10046560  tt9916800  tvEpisode
# 10046561  tt9916802  tvEpisode
# 10046562  tt9916804  tvEpisode
# 10046563  tt9916806  tvEpisode
# 10046564  tt9916808  tvEpisode
# 10046565  tt9916810  tvEpisode
# 10046566  tt9916812  tvEpisode
# ...

# %%
df1=df[df["genres"] == "Horror"]

# %%
df1
# Out:
#              tconst  titleType        primaryTitle       originalTitle  \
# 3983      tt0004026      movie           The Golem           Der Golem
# 4517      tt0004573      movie  Ein seltsamer Fall  Ein seltsamer Fall
# 6163      tt0006238      movie  Zhenshchina vampir  Zhenshchina vampir
# 7640      tt0007744      movie  The Brand of Satan  The Brand of Satan
# 7875      tt0007983      movie              Furcht              Furcht
# ...             ...        ...                 ...                 ...
# 10043702  tt9910674  tvEpisode       Episode #1.25       Episode #1.25
# 10043704  tt9910678  tvEpisode       Episode #1.26       Episode #1.26
# 10043837  tt9910964      movie          Hellavator          Hellavator
# 10044021  tt9911336      movie          Hellavator          Hellavator
# 10045818  tt9915164      movie         #WorstThing         #WorstThing
#
#          isAdult startYear endYear runtimeMinutes  genres
# ...

# %%
horror_movies = df[df['genres'].str.contains('Horror', case=False, na=False)]

# %%
horror_movies_df=pd.DataFrame(horror_movies)

# %%
horror_movies_df.tail(50)
# Out:
#              tconst  titleType  \
# 10041922  tt9906778  tvEpisode
# 10042408  tt9907782      movie
# 10042707  tt9908416  tvEpisode
# 10042718  tt9908440      short
# 10042793  tt9908610  tvEpisode
# 10042965  tt9908992  tvEpisode
# 10042980  tt9909044  tvEpisode
# 10043024  tt9909156  tvEpisode
# 10043038  tt9909186      short
# 10043044  tt9909206  tvEpisode
# 10043058  tt9909244  tvEpisode
# 10043067  tt9909264  tvEpisode
# 10043210  tt9909570  videoGame
# 10043223  tt9909602      short
# 10043262  tt9909688      short
# 10043269  tt9909706      short
# 10043289  tt9909762  tvEpisode
# 10043315  tt9909830      video
# 10043335  tt9909874      video
# 10043340  tt9909884  tvEpisode
# 10043344  tt9909892  tvEpisode
# 10043345  tt9909896  tvEpisode
# 10043355  tt9909916      video
# 10043368  tt9909954      video
# 10043379  tt9909990      short
# 10043395  tt9910024      video
# 10043407  tt9910050      short
# 10043456  tt9910160      video
# 10043470  tt9910190      short
# ...

# %%
horror_movies_df.shape
# Out:
# (179025, 9)

# %%
horror_movies_ids=horror_movies_df['tconst']

# %%
horror_movies_ids
# Out:
# 73          tt0000075
# 89          tt0000091
# 129         tt0000131
# 135         tt0000138
# 149         tt0000152
#               ...
# 10045818    tt9915164
# 10045833    tt9915200
# 10045978    tt9915514
# 10046117    tt9915862
# 10046298    tt9916248
# Name: tconst, Length: 179025, dtype: object

# %%
df.titleType.unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvSeries', 'tvEpisode',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
df1=df[df['titleType']=='movie']

# %%
df1
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10046479  tt9916622     movie
# 10046506  tt9916680     movie
# 10046518  tt9916706     movie
# 10046528  tt9916730     movie
# 10046538  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 10046479        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10046506  De la ilusión al desconcierto: cine colombiano...
# ...

# %%
df1=horror_movies_df[horror_movies_df['titleType']=='movie']

# %%
df1
# Out:
#              tconst titleType  \
# 3385      tt0003419     movie
# 3607      tt0003643     movie
# 3971      tt0004013     movie
# 3983      tt0004026     movie
# 4076      tt0004121     movie
# ...             ...       ...
# 10043635  tt9910530     movie
# 10043837  tt9910964     movie
# 10044021  tt9911336     movie
# 10045668  tt9914808     movie
# 10045818  tt9915164     movie
#
#                                                primaryTitle  \
# 3385                                  The Student of Prague
# 3607      The Avenging Conscience: or 'Thou Shalt Not Kill'
# 3971                                      The Ghost Breaker
# 3983                                              The Golem
# 4076                   The Hound of the Baskervilles (1914)
# ...                                                     ...
# 10043635                                         Svartklubb
# 10043837                                         Hellavator
# ...

# %%
df1.startYear.unique()
# Out:
# array(['1913', '1914', '1915', '1916', '1917', '1918', '1919', '1920',
#        '1924', '1921', '1922', '1923', '1925', '1926', '1928', '1927',
#        '1929', '1930', '1931', '1932', '1933', '1934', '1935', '1936',
#        '1937', '1939', '1938', '1940', '1941', '1942', '1943', '1944',
#        '1945', '1947', '1946', '1948', '1949', '1951', '1962', '1950',
#        '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959',
#        '1960', '1961', '1965', '1963', '1971', '1964', '1966', '1968',
#        '1967', '1969', '1970', '1972', '1974', '1973', '1978', '1985',
#        '1975', '1976', '1977', '1984', '1982', '1980', '1979', '1981',
#        '1983', '1989', '1987', '1986', '2005', '1988', '1991', '1990',
#        '1992', '1993', '1994', '1995', '2017', '1997', '1996', '1999',
#        '1998', '2001', '2002', '2004', '2000', '2003', '\\N', '1912',
#        '2021', '2006', '2009', '2007', '2008', '2011', '2012', '2010',
# ...

# %%
df2=horror_movies_df.loc[horror_movies_df['titleType'].isin(['movie','tvMovie'])]

# %%
df2
# Out:
#              tconst titleType  \
# 3385      tt0003419     movie
# 3607      tt0003643     movie
# 3971      tt0004013     movie
# 3983      tt0004026     movie
# 4076      tt0004121     movie
# ...             ...       ...
# 10043837  tt9910964     movie
# 10044021  tt9911336     movie
# 10045668  tt9914808     movie
# 10045818  tt9915164     movie
# 10046298  tt9916248   tvMovie
#
#                                                primaryTitle  \
# 3385                                  The Student of Prague
# 3607      The Avenging Conscience: or 'Thou Shalt Not Kill'
# 3971                                      The Ghost Breaker
# 3983                                              The Golem
# 4076                   The Hound of the Baskervilles (1914)
# ...                                                     ...
# 10043837                                         Hellavator
# 10044021                                         Hellavator
# ...

# %%
df2=df2.drop_duplicates('primaryTitle')

# %%
df2
# Out:
#              tconst titleType  \
# 3385      tt0003419     movie
# 3607      tt0003643     movie
# 3971      tt0004013     movie
# 3983      tt0004026     movie
# 4076      tt0004121     movie
# ...             ...       ...
# 10043635  tt9910530     movie
# 10043837  tt9910964     movie
# 10045668  tt9914808     movie
# 10045818  tt9915164     movie
# 10046298  tt9916248   tvMovie
#
#                                                primaryTitle  \
# 3385                                  The Student of Prague
# 3607      The Avenging Conscience: or 'Thou Shalt Not Kill'
# 3971                                      The Ghost Breaker
# 3983                                              The Golem
# 4076                   The Hound of the Baskervilles (1914)
# ...                                                     ...
# 10043635                                         Svartklubb
# 10043837                                         Hellavator
# ...

# %%
df2.tail(50)
# Out:
#              tconst titleType  \
# 10024134  tt9868158     movie
# 10024349  tt9868600     movie
# 10024551  tt9869038     movie
# 10024680  tt9869320     movie
# 10024820  tt9869668     movie
# 10025881  tt9872038     movie
# 10026142  tt9872616     movie
# 10027412  tt9875310     movie
# 10027477  tt9875452     movie
# 10027486  tt9875472     movie
# 10027863  tt9876298     movie
# 10027912  tt9876416     movie
# 10028047  tt9876728   tvMovie
# 10029262  tt9879394     movie
# 10029379  tt9879636     movie
# 10030177  tt9881330     movie
# 10030336  tt9881678     movie
# 10030501  tt9882054     movie
# 10030932  tt9883042     movie
# 10030962  tt9883128     movie
# 10031035  tt9883284     movie
# 10031390  tt9884054     movie
# 10032705  tt9886784     movie
# 10033044  tt9887544     movie
# 10033138  tt9887790     movie
# 10034218  tt9890120     movie
# 10035050  tt9891874     movie
# 10035453  tt9892852     movie
# 10035577  tt9893130     movie
# 10035890  tt9893824     movie
# ...
